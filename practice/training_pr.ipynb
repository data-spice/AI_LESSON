# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("../datasets/customer.csv")
df.head()
# Out:
#    Age  Annual_Income  Spending_Score  Distance_From_Store  Purchase
# 0   22          25000              85                  2.5         1
# 1   35          75000              42                 15.2         0
# 2   28          42000              78                  4.1         1
# 3   45         120000              35                 22.8         0
# 4   31          55000              91                  3.2         1

# %%
sns.scatterplot(data=df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Age  Annual_Income  Spending_Score  Distance_From_Store  Purchase
# 0   22          25000              85                  2.5         1
# 1   35          75000              42                 15.2         0
# 2   28          42000              78                  4.1         1
# 3   45         120000              35                 22.8         0
# 4   31          55000              91                  3.2         1

# %%
x=df.drop(columns=['Purchase'])
x.head()
# Out:
#    Age  Annual_Income  Spending_Score  Distance_From_Store
# 0   22          25000              85                  2.5
# 1   35          75000              42                 15.2
# 2   28          42000              78                  4.1
# 3   45         120000              35                 22.8
# 4   31          55000              91                  3.2

# %%
y=df["Purchase"]
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Purchase, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,random_state=34,test_size=0.2)

# %%
sns.boxplot(X_train)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
sns.scatterplot(X_train)
# Out:
# <Axes: >

# %%
sns.boxplot(X_train)
# Out:
# <Axes: >
