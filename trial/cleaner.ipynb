# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("../datasets/mcu.csv")
df
# Out:
#                                        movie_title mcu_phase release_date  \
# 0                                         Iron Man   Phase 1   2008-05-02
# 1                              The Incredible Hulk   Phase 1   2008-06-13
# 2                                       Iron Man 2   Phase 1   2010-05-07
# 3                                             Thor   Phase 1   2011-05-06
# 4                Captain America The First Avenger   Phase 1   2011-07-22
# ..                                             ...       ...          ...
# 57                                      Wonder Man   Phase 6   2026-01-27
# 58  Your Friendly Neighborhood Spider-Man Season 2   Phase 6   2026-09-01
# 59                   Daredevil Born Again Season 2   Phase 6   2026-03-24
# 60                      The Punisher One Last Kill   Phase 6   2026-05-12
# 61                              X-Men '97 Season 2   Phase 6   2026-08-01
#
#     tomato_meter  audience_score  movie_duration  production_budget  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_title           62 non-null     str
#  1   mcu_phase             62 non-null     str
#  2   release_date          62 non-null     str
#  3   tomato_meter          62 non-null     int64
#  4   audience_score        62 non-null     int64
#  5   movie_duration        38 non-null     float64
#  6   production_budget     38 non-null     float64
#  7   opening_weekend       38 non-null     float64
#  8   domestic_box_office   38 non-null     float64
#  9   worldwide_box_office  38 non-null     float64
# dtypes: float64(5), int64(2), str(3)
# memory usage: 7.2 KB

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_title           38 non-null     str
#  1   mcu_phase             38 non-null     str
#  2   release_date          38 non-null     str
#  3   tomato_meter          38 non-null     int64
#  4   audience_score        38 non-null     int64
#  5   movie_duration        38 non-null     float64
#  6   production_budget     38 non-null     float64
#  7   opening_weekend       38 non-null     float64
#  8   domestic_box_office   38 non-null     float64
#  9   worldwide_box_office  38 non-null     float64
# dtypes: float64(5), int64(2), str(3)
# memory usage: 4.5 KB

# %%
np.unique(df['tomato_meter'])
# Out:
# array([46, 47, 48, 62, 63, 66, 67, 72, 73, 76, 77, 79, 80, 82, 83, 84, 85,
#        86, 87, 88, 89, 90, 91, 92, 93, 94, 96])

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df)
# Out:
# <Axes: >
