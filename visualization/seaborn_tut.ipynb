# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
mpg=sns.load_dataset("mpg")
sns.set_theme()
# sns.set_style("darkgrid")

sns.scatterplot(data=mpg,x="weight",y="mpg")
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
mpg.corr(numeric_only=True)
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
sns.heatmap(mpg.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=mpg,x='weight',y="mpg",hue='origin',palette='mako')
sns.despine(left=True)

# %%
sns.lineplot(data=mpg,x="model_year",y='mpg')
# Out:
# <Axes: xlabel='model_year', ylabel='mpg'>

# %%
sns.pointplot(data=mpg,x='model_year',y='mpg',hue='origin')
# Out:
# <Axes: xlabel='model_year', ylabel='mpg'>

# %%
sns.kdeplot(data=mpg,x="weight" \
"",y='mpg',fill=True)
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
sns.histplot(data=mpg,x='weight',y='mpg')
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
sns.histplot(mpg['mpg'],kde=True,bins=3)
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
sns.kdeplot(mpg["mpg"])
# Out:
# <Axes: xlabel='mpg', ylabel='Density'>

# %%
sns.ecdfplot(mpg["mpg"])
# Out:
# <Axes: xlabel='mpg', ylabel='Proportion'>

# %%
sns.rugplot(mpg['mpg'])
# Out:
# <Axes: xlabel='mpg'>

# %%
sns.countplot(mpg['origin'])
# Out:
# <Axes: xlabel='count', ylabel='origin'>

# %%
sns.boxenplot(data=mpg, x="origin", y="mpg",hue='origin',palette="Set2")
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(data=mpg, x="origin", y="mpg",hue='origin',palette="Set2")
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.violinplot(mpg,x="origin",y="mpg",hue='origin')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.stripplot(mpg,x="origin",y="mpg",hue='origin')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
sns.jointplot(mpg,x="weight",y="mpg")

# %%
sns.jointplot(mpg,x="weight",y="mpg",kind='kde',fill=True)

# %%
sns.pairplot(data=mpg,hue=
'origin')

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips,x="total_bill",y='tip',col='sex')
